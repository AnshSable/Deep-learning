# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv('E:\Deep-learning\Regresssion_problem\Admission_Prediction.csv')

# %%
df.head()
# Out:
#    Serial_No.  GRE_Score  TOEFL_Score  University_Rating  SOP  LOR  CGPA  \
# 0           1      337.0        118.0                  4  4.5  4.5  9.65
# 1           2      324.0        107.0                  4  4.0  4.5  8.87
# 2           3      316.0        104.0                  3  3.0  3.5  8.00
# 3           4      322.0        110.0                  3  3.5  2.5  8.67
# 4           5      314.0        103.0                  2  2.0  3.0  8.21
#
#   Research  Chance_of_Admit
# 0      Yes             0.92
# 1      Yes             0.76
# 2      Yes             0.72
# 3      Yes             0.80
# 4       No             0.65

# %%
df.shape
# Out:
# (505, 9)

# %%
df.drop(columns=['Serial_No.'],inplace=True)

# %%
df.head()
# Out:
#    GRE_Score  TOEFL_Score  University_Rating  SOP  LOR  CGPA Research  \
# 0      337.0        118.0                  4  4.5  4.5  9.65      Yes
# 1      324.0        107.0                  4  4.0  4.5  8.87      Yes
# 2      316.0        104.0                  3  3.0  3.5  8.00      Yes
# 3      322.0        110.0                  3  3.5  2.5  8.67      Yes
# 4      314.0        103.0                  2  2.0  3.0  8.21       No
#
#    Chance_of_Admit
# 0             0.92
# 1             0.76
# 2             0.72
# 3             0.80
# 4             0.65

# %%
X = df.iloc[:,0:-1]
y = df.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=1)

# %%
X_train
# Out:
#      GRE_Score  TOEFL_Score  University_Rating  SOP  LOR  CGPA
# 442      318.0        110.0                  1  2.5  3.5  8.54
# 42       313.0        107.0                  2  2.5  2.0  8.50
# 58       300.0         99.0                  1  3.0  2.0  6.80
# 481      309.0        105.0                  4  3.5  2.0  8.18
# 78       296.0         95.0                  2  3.0  2.0  7.54
# ..         ...          ...                ...  ...  ...   ...
# 255      318.0        100.0                  2  2.5  3.5  8.54
# 72       321.0        111.0                  5  5.0  5.0  9.45
# 396      326.0        112.0                  4  4.0  3.5  9.12
# 235      312.0        107.0                  2  2.5  3.5  8.27
# 37       300.0        105.0                  1  1.0  2.0  7.80
#
# [404 rows x 6 columns]

# %%
df.drop(columns=['Research'],inplace=True)
df.head()
# Out:
#    GRE_Score  TOEFL_Score  University_Rating  SOP  LOR  CGPA  Chance_of_Admit
# 0      337.0        118.0                  4  4.5  4.5  9.65             0.92
# 1      324.0        107.0                  4  4.0  4.5  8.87             0.76
# 2      316.0        104.0                  3  3.0  3.5  8.00             0.72
# 3      322.0        110.0                  3  3.5  2.5  8.67             0.80
# 4      314.0        103.0                  2  2.0  3.0  8.21             0.65

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
X_test
X_test_scaled
# Out:
# array([[ 0.46      ,  0.5       ,  0.25      ,  0.375     ,  0.14285714,
#          0.5224359 ],
#        [ 0.44      ,  0.53571429,  0.5       ,  0.5       ,  0.42857143,
#          0.53205128],
#        [ 0.98      ,  0.96428571,  1.        ,  0.875     ,  0.71428571,
#          0.92948718],
#        [ 0.52      ,  0.53571429,  0.25      ,  0.625     ,  0.57142857,
#          0.58974359],
#        [ 0.48      ,  0.46428571,  0.25      ,  0.375     ,  0.14285714,
#          0.26923077],
#        [ 0.38      ,  0.46428571,  1.        ,  0.625     ,  0.57142857,
#          0.56410256],
#        [ 0.46      ,  0.60714286,  0.5       ,  0.75      ,  0.57142857,
#          0.70512821],
#        [ 0.74      ,  0.39285714,  0.5       ,  0.75      ,  0.71428571,
#          0.48076923],
#        [ 0.64      ,  0.71428571,  0.75      ,  0.875     ,  0.85714286,
#          0.78846154],
#        [ 0.56      ,  0.5       ,  0.25      ,  0.75      ,  0.71428571,
#          0.77884615],
#        [ 0.4       ,  0.25      ,  0.25      ,  0.125     ,  0.14285714,
#          0.16025641],
#        [ 0.96      ,  0.89285714,  0.75      ,  0.625     ,  0.85714286,
#          0.8525641 ],
#        [ 0.28      ,  0.53571429,  0.5       ,  0.625     ,  0.42857143,
#          0.33974359],
#        [ 0.52      ,  0.35714286,  0.25      ,  0.75      ,  0.57142857,
#          0.43269231],
#        [ 0.44      ,  0.5       ,  0.5       ,  0.75      ,  0.57142857,
#          0.63782051],
#        [ 0.14      ,  0.28571429,  0.        ,  0.125     ,  0.14285714,
#          0.3525641 ],
#        [        nan,  0.42857143,  0.75      ,  1.        ,  1.        ,
#          0.71153846],
#        [ 0.72      ,  0.71428571,  0.5       ,  0.625     ,  0.42857143,
#          0.73717949],
#        [ 0.        ,  0.42857143,  0.75      ,  0.25      ,  0.28571429,
#          0.21153846],
#        [ 0.82      ,  0.82142857,  1.        ,  0.875     ,  0.57142857,
#          0.82051282],
#        [ 0.42      ,  0.42857143,  0.5       ,  0.75      ,  0.57142857,
#          0.42628205],
#        [ 0.18      ,  0.07142857,  0.        ,  0.        , -0.14285714,
#          0.17307692],
#        [ 0.54      ,  0.28571429,  0.25      ,  0.5       ,  0.28571429,
#          0.56730769],
#        [ 0.34      ,  0.46428571,  0.25      ,  0.375     ,  0.85714286,
#          0.42307692],
#        [ 0.48      ,  0.53571429,  0.25      ,  0.375     ,  0.71428571,
#          0.47115385],
#        [ 0.14      ,  0.25      ,  0.75      ,  0.5       ,  0.57142857,
#          0.32371795],
#        [ 0.48      ,  0.60714286,  0.75      ,  0.625     ,  0.71428571,
#          0.63141026],
#        [ 0.42      ,  0.25      ,  0.        ,  0.375     ,  0.42857143,
#          0.5224359 ],
#        [ 0.62      ,  0.78571429,  0.75      ,  0.75      ,  1.        ,
#          0.74358974],
#        [ 0.42      ,  0.32142857,  0.25      ,  0.375     ,  0.57142857,
#          0.49358974],
#        [ 0.62      ,  0.60714286,  0.5       ,  0.5       ,  0.71428571,
#          0.44871795],
#        [ 0.64      ,  0.71428571,  0.75      ,  0.625     ,  0.28571429,
#          0.71153846],
#        [ 0.74      ,         nan,  0.75      ,  0.75      ,  0.85714286,
#          0.70512821],
#        [ 0.84      ,  0.57142857,  1.        ,  0.875     ,  0.71428571,
#          0.71153846],
#        [ 0.16      ,  0.21428571,  0.25      ,  0.75      ,  0.42857143,
#          0.39423077],
#        [ 0.68      ,  0.75      ,  0.75      ,  0.875     ,  0.71428571,
#          0.63782051],
#        [ 0.3       ,  0.57142857,  1.        ,  0.5       ,  0.42857143,
#          0.53846154],
#        [ 0.62      ,  0.71428571,  0.5       ,  0.5       ,  0.85714286,
#          0.68910256]])

# %%
import tensorflow 
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
model =Sequential()
model.add(Dense(7, activation='relu', input_dim=6))
model.add(Dense(1, activation='linear'))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 model =Sequential()
#       2 model.add(Dense(7, activation='relu', input_dim=6))
#       3 model.add(Dense(1, activation='linear'))
#
# File ~\AppData\Roaming\Python\Python310\site-packages\keras\src\models\sequential.py:67, in Sequential.__new__(cls, *args, **kwargs)
#      66 def __new__(cls, *args, **kwargs):
# ---> 67     return typing.cast(cls, super().__new__(cls))
#
# File ~\AppData\Roaming\Python\Python310\site-packages\keras\src\models\model.py:146, in Model.__new__(cls, *args, **kwargs)
#     143     from keras.src.models.functional import Functional
#     145     return Functional.__new__(Functional, *args, **kwargs)
# --> 146 return typing.cast(cls, super().__new__(cls))
#
# File ~\AppData\Roaming\Python\Python310\site-packages\keras\src\layers\layer.py:222, in Layer.__new__(cls, *args, **kwargs)
#     221 def __new__(cls, *args, **kwargs):
# --> 222     obj = super().__new__(cls, *args, **kwargs)
#     224     # Wrap the user-provided `build` method in the `build_wrapper`
#     225     # to add name scope support and serialization support.
#     226     original_build_method = obj.build
#
# File ~\AppData\Roaming\Python\Python310\site-packages\keras\src\ops\operation.py:151, in Operation.__new__(cls, *args, **kwargs)
#     149     auto_config = False
#     150 try:
# --> 151     instance._lock = False
#     152     if auto_config:
#     153         from keras.src.saving import serialization_lib
#
# File ~\AppData\Roaming\Python\Python310\site-packages\keras\src\layers\layer.py:1533, in Layer.__setattr__(self, name, value)
#    1531 if name != "_tracker":
#    1532     if not hasattr(self, "_tracker"):
# -> 1533         self._initialize_tracker()
#    1534     value = self._tracker.track(value)
#    1535 return super().__setattr__(name, value)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\keras\src\utils\tracking.py:26, in no_automatic_dependency_tracking.<locals>.wrapper(*args, **kwargs)
#      23 @wraps(fn)
#      24 def wrapper(*args, **kwargs):
#      25     with DotNotTrackScope():
# ---> 26         return fn(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\keras\src\layers\layer.py:348, in Layer._initialize_tracker(self)
#     346 metrics = []
#     347 seed_generators = []
# --> 348 self._tracker = tracking.Tracker(
#     349     {
#     350         "trainable_variables": (
#     351             lambda x: isinstance(x, backend.Variable) and x.trainable,
#     352             trainable_variables,
#     353         ),
#     354         "non_trainable_variables": (
#     355             lambda x: isinstance(x, backend.Variable)
#     356             and not x.trainable,
#     357             non_trainable_variables,
#     358         ),
#     359         "metrics": (lambda x: isinstance(x, Metric), metrics),
#     360         "layers": (
#     361             lambda x: isinstance(x, Layer)
#     362             and not isinstance(x, Metric),
#     363             layers,
#     364         ),
#     365         "seed_generators": (
#     366             lambda x: isinstance(x, backend.random.SeedGenerator),
#     367             seed_generators,
#     368         ),
#     369     },
#     370     exclusions={"non_trainable_variables": ["trainable_variables"]},
#     371 )
#     372 if backend.backend() == "tensorflow":
#     373     # Remove attribute tracking for lists (TF-specific attribute)
#     374     _self_setattr_tracking = getattr(
#     375         self, "_self_setattr_tracking", True
#     376     )
#
# File ~\AppData\Roaming\Python\Python310\site-packages\keras\src\layers\layer.py:1535, in Layer.__setattr__(self, name, value)
#    1533         self._initialize_tracker()
#    1534     value = self._tracker.track(value)
# -> 1535 return super().__setattr__(name, value)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\keras\src\backend\tensorflow\trackable.py:28, in KerasAutoTrackable.__setattr__(self, name, value)
#      24 if getattr(self, "_self_setattr_tracking", True):
#      25     value = sticky_attribute_assignment(
#      26         trackable=self, value=value, name=name
#      27     )
# ---> 28 super().__setattr__(name, value)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow\python\trackable\autotrackable.py:68, in AutoTrackable.__setattr__(self, name, value)
#      65   pass
#      67 if getattr(self, "_self_setattr_tracking", True):
# ---> 68   value = data_structures.sticky_attribute_assignment(
#      69       trackable=self, value=value, name=name)
#      70 super(AutoTrackable, self).__setattr__(name, value)
#
# AttributeError: module 'tensorflow.python.trackable.data_structures' has no attribute 'sticky_attribute_assignment'
